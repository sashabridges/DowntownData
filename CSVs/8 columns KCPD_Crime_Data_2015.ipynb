# %%
import pandas as pd
file = r"C:\Users\Matt\Pictures\KCPD_Crime_Data_2015.csv"

# %%
df = pd.read_csv(file)
df.head(15)
# Out:
#     Report_No Reported_Date Reported Time   From_Date From Time  \
# 0   150015427    03/06/2015          0:02  03/06/2015      0:02
# 1    70045155    09/21/2015         14:20  01/19/2015       NaN
# 2    70045155    09/21/2015         14:20  01/19/2015       NaN
# 3   150057463    09/08/2015          1:17  09/08/2015      1:17
# 4   150033873    05/19/2015          0:21  05/19/2015      0:21
# 5   150061779    08/31/2015         10:28  08/31/2015      8:00
# 6   150087307    12/04/2015          2:57  12/04/2015      2:57
# 7   150091950    12/28/2015          9:18  12/23/2015      9:00
# 8   150059325    08/21/2015         21:45  08/21/2015     21:43
# 9   150057467    08/15/2015          2:56  08/15/2015      2:56
# 10  150009894    02/10/2015         10:03  02/09/2015     18:30
# 11  150009910    02/10/2015         12:14  02/10/2015      9:50
# 12  150041636    06/17/2015         21:12  06/17/2015     21:00
# 13  150074376    10/15/2015         23:36         NaN       NaN
# ...

# %%
df.columns
# Out:
# Index(['Report_No', 'Reported_Date', 'Reported Time', 'From_Date', 'From Time',
#        'To_Date', 'To Time', 'Offense', 'IBRS', 'Description', 'Beat',
#        'Address', 'City', 'Zip Code', 'Rep_Dist', 'Area', 'DVFlag', 'Invl_No',
#        'Involvement', 'Race', 'Sex', 'Age', 'Firearm Used Flag', 'Latitude',
#        'Longitude', 'Location 1', 'Neighborhood Census', 'Council Districts',
#        'County Boundary', 'Zip Codes'],
#       dtype='object')

# %%
clean_df = df.drop(["Reported_Date", "Reported Time", "To_Date", "To Time", "IBRS", "Description", "Beat", "Address", "City", "Rep_Dist", "Area", "Invl_No", "Involvement", "Age", "Latitude", "Longitude", "Location 1", "Neighborhood Census", "Council Districts", "County Boundary", "Zip Codes"], axis=1)
clean_df.head()
# Out:
#    Report_No   From_Date From Time  Offense  Zip Code DVFlag Race  Sex  \
# 0  150015427  03/06/2015      0:02     2601     64131      U  NaN  NaN
# 1   70045155  01/19/2015       NaN      401     99999      U    B    M
# 2   70045155  01/19/2015       NaN     2001     99999      U    B    M
# 3  150057463  09/08/2015      1:17      702     64126      U    U    U
# 4  150033873  05/19/2015      0:21     1849     64128      U  NaN  NaN
#
#   Firearm Used Flag
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
